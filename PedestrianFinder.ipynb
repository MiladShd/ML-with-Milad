# %% [markdown]
# <a href="https://colab.research.google.com/github/MiladShd/ML-with-Milad/blob/main/PedestrianFinder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
import torch

# Check if CUDA (GPU support) is available
if torch.cuda.is_available():
    print("GPU is enabled!")
    print(f"Device name: {torch.cuda.get_device_name(0)}")
else:
    print("GPU is not enabled. Running on CPU.")
# Out:
# GPU is enabled!
# Device name: NVIDIA A100-SXM4-40GB

# %%
# !wget https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip -P data
# !unzip data/PennFudanPed.zip -d data
# %cd data
# Out:
# --2024-09-23 16:32:50--  https://www.cis.upenn.edu/~jshi/ped_html/PennFudanPed.zip
# Resolving www.cis.upenn.edu (www.cis.upenn.edu)... 158.130.69.163, 2607:f470:8:64:5ea5::d
# Connecting to www.cis.upenn.edu (www.cis.upenn.edu)|158.130.69.163|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53723336 (51M) [application/zip]
# Saving to: ‘data/PennFudanPed.zip’
#
# PennFudanPed.zip    100%[===================>]  51.23M  8.05MB/s    in 43s
#
# 2024-09-23 16:33:34 (1.20 MB/s) - ‘data/PennFudanPed.zip’ saved [53723336/53723336]
#
# Archive:  data/PennFudanPed.zip
#    creating: data/PennFudanPed/
#   inflating: data/PennFudanPed/added-object-list.txt
#    creating: data/PennFudanPed/Annotation/
#   inflating: data/PennFudanPed/Annotation/FudanPed00001.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00002.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00003.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00004.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00005.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00006.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00007.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00008.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00009.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00010.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00011.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00012.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00013.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00014.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00015.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00016.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00017.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00018.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00019.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00020.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00021.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00022.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00023.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00024.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00025.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00026.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00027.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00028.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00029.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00030.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00031.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00032.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00033.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00034.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00035.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00036.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00037.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00038.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00039.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00040.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00041.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00042.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00043.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00044.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00045.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00046.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00047.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00048.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00049.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00050.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00051.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00052.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00053.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00054.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00055.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00056.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00057.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00058.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00059.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00060.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00061.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00062.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00063.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00064.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00065.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00066.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00067.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00068.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00069.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00070.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00071.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00072.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00073.txt
#   inflating: data/PennFudanPed/Annotation/FudanPed00074.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00001.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00002.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00003.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00004.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00005.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00006.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00007.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00008.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00009.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00010.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00011.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00012.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00013.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00014.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00015.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00016.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00017.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00018.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00019.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00020.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00021.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00022.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00023.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00024.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00025.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00026.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00027.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00028.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00029.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00030.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00031.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00032.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00033.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00034.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00035.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00036.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00037.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00038.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00039.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00040.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00041.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00042.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00043.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00044.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00045.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00046.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00047.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00048.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00049.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00050.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00051.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00052.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00053.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00054.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00055.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00056.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00057.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00058.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00059.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00060.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00061.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00062.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00063.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00064.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00065.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00066.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00067.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00068.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00069.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00070.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00071.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00072.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00073.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00074.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00075.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00076.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00077.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00078.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00079.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00080.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00081.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00082.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00083.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00084.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00085.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00086.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00087.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00088.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00089.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00090.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00091.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00092.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00093.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00094.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00095.txt
#   inflating: data/PennFudanPed/Annotation/PennPed00096.txt
#    creating: data/PennFudanPed/PedMasks/
#   inflating: data/PennFudanPed/PedMasks/FudanPed00001_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00002_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00003_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00004_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00005_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00006_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00007_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00008_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00009_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00010_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00011_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00012_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00013_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00014_mask.png
#  extracting: data/PennFudanPed/PedMasks/FudanPed00015_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00016_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00017_mask.png
#  extracting: data/PennFudanPed/PedMasks/FudanPed00018_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00019_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00020_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00021_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00022_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00023_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00024_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00025_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00026_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00027_mask.png
#  extracting: data/PennFudanPed/PedMasks/FudanPed00028_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00029_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00030_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00031_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00032_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00033_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00034_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00035_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00036_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00037_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00038_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00039_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00040_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00041_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00042_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00043_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00044_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00045_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00046_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00047_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00048_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00049_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00050_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00051_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00052_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00053_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00054_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00055_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00056_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00057_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00058_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00059_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00060_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00061_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00062_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00063_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00064_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00065_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00066_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00067_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00068_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00069_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00070_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00071_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00072_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00073_mask.png
#   inflating: data/PennFudanPed/PedMasks/FudanPed00074_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00001_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00002_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00003_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00004_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00005_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00006_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00007_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00008_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00009_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00010_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00011_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00012_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00013_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00014_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00015_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00016_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00017_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00018_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00019_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00020_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00021_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00022_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00023_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00024_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00025_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00026_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00027_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00028_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00029_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00030_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00031_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00032_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00033_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00034_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00035_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00036_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00037_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00038_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00039_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00040_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00041_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00042_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00043_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00044_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00045_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00046_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00047_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00048_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00049_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00050_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00051_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00052_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00053_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00054_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00055_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00056_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00057_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00058_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00059_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00060_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00061_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00062_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00063_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00064_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00065_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00066_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00067_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00068_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00069_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00070_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00071_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00072_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00073_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00074_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00075_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00076_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00077_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00078_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00079_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00080_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00081_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00082_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00083_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00084_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00085_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00086_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00087_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00088_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00089_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00090_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00091_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00092_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00093_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00094_mask.png
#   inflating: data/PennFudanPed/PedMasks/PennPed00095_mask.png
#  extracting: data/PennFudanPed/PedMasks/PennPed00096_mask.png
#    creating: data/PennFudanPed/PNGImages/
#   inflating: data/PennFudanPed/PNGImages/FudanPed00001.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00002.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00003.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00004.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00005.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00006.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00007.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00008.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00009.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00010.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00011.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00012.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00013.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00014.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00015.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00016.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00017.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00018.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00019.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00020.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00021.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00022.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00023.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00024.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00025.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00026.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00027.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00028.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00029.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00030.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00031.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00032.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00033.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00034.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00035.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00036.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00037.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00038.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00039.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00040.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00041.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00042.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00043.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00044.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00045.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00046.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00047.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00048.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00049.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00050.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00051.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00052.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00053.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00054.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00055.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00056.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00057.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00058.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00059.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00060.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00061.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00062.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00063.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00064.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00065.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00066.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00067.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00068.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00069.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00070.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00071.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00072.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00073.png
#   inflating: data/PennFudanPed/PNGImages/FudanPed00074.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00001.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00002.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00003.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00004.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00005.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00006.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00007.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00008.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00009.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00010.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00011.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00012.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00013.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00014.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00015.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00016.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00017.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00018.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00019.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00020.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00021.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00022.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00023.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00024.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00025.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00026.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00027.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00028.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00029.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00030.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00031.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00032.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00033.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00034.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00035.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00036.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00037.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00038.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00039.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00040.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00041.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00042.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00043.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00044.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00045.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00046.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00047.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00048.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00049.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00050.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00051.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00052.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00053.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00054.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00055.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00056.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00057.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00058.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00059.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00060.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00061.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00062.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00063.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00064.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00065.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00066.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00067.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00068.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00069.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00070.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00071.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00072.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00073.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00074.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00075.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00076.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00077.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00078.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00079.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00080.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00081.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00082.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00083.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00084.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00085.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00086.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00087.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00088.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00089.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00090.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00091.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00092.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00093.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00094.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00095.png
#   inflating: data/PennFudanPed/PNGImages/PennPed00096.png
#   inflating: data/PennFudanPed/readme.txt
# /content/data

# %%
import matplotlib.pyplot as plt
from torchvision.io import read_image


image = read_image("PennFudanPed/PNGImages/PennPed00089.png")
mask = read_image("PennFudanPed/PedMasks/PennPed00089_mask.png")

plt.figure(figsize=(16, 8))
plt.subplot(121)
plt.title("Image")
plt.imshow(image.permute(1, 2, 0))
plt.subplot(122)
plt.title("Mask")
plt.imshow(mask.permute(1, 2, 0))

# %%
import os
import torch

from torchvision.io import read_image
from torchvision.ops.boxes import masks_to_boxes
from torchvision import tv_tensors
from torchvision.transforms.v2 import functional as F


class PennFudanDataset(torch.utils.data.Dataset):
    def __init__(self, root, transforms):
        self.root = root
        self.transforms = transforms
        # load all image files, sorting them to ensure that they are aligned
        self.imgs = list(sorted(os.listdir(os.path.join(root, "PNGImages"))))
        self.masks = list(sorted(os.listdir(os.path.join(root, "PedMasks"))))

    def __getitem__(self, idx):
        # load images and masks
        img_path = os.path.join(self.root, "PNGImages", self.imgs[idx])
        mask_path = os.path.join(self.root, "PedMasks", self.masks[idx])
        img = read_image(img_path)
        mask = read_image(mask_path)
        # instances are encoded as different colors
        obj_ids = torch.unique(mask)
        # first id is the background, so remove it
        obj_ids = obj_ids[1:]
        num_objs = len(obj_ids)

        # split the color-encoded mask into a set of binary masks
        masks = (mask == obj_ids[:, None, None]).to(dtype=torch.uint8)

        # get bounding box coordinates for each mask
        boxes = masks_to_boxes(masks)

        # there is only one class
        labels = torch.ones((num_objs,), dtype=torch.int64)

        image_id = idx
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_objs,), dtype=torch.int64)

        # Wrap sample and targets into torchvision tv_tensors:
        img = tv_tensors.Image(img)

        target = {}
        target["boxes"] = tv_tensors.BoundingBoxes(boxes, format="XYXY", canvas_size=F.get_size(img))
        target["masks"] = tv_tensors.Mask(masks)
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self):
        return len(self.imgs)

# %%
import torchvision
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor


def get_model_instance_segmentation(num_classes):
    # load an instance segmentation model pre-trained on COCO
    model = torchvision.models.detection.maskrcnn_resnet50_fpn(weights="DEFAULT")

    # get number of input features for the classifier
    in_features = model.roi_heads.box_predictor.cls_score.in_features
    # replace the pre-trained head with a new one
    model.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)

    # now get the number of input features for the mask classifier
    in_features_mask = model.roi_heads.mask_predictor.conv5_mask.in_channels
    hidden_layer = 256
    # and replace the mask predictor with a new one
    model.roi_heads.mask_predictor = MaskRCNNPredictor(
        in_features_mask,
        hidden_layer,
        num_classes
    )

    return model

# %%
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py")
os.system("wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py")
# Out:
# 0

# %%
from torchvision.transforms import v2 as T


def get_transform(train):
    transforms = []
    if train:
        transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToDtype(torch.float, scale=True))
    transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

# %%
import utils

model = torchvision.models.detection.fasterrcnn_resnet50_fpn(weights="DEFAULT")
dataset = PennFudanDataset('PennFudanPed/', get_transform(train=True))
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    collate_fn=utils.collate_fn
)

# For Training
images, targets = next(iter(data_loader))
images = list(image for image in images)
targets = [{k: v for k, v in t.items()} for t in targets]
output = model(images, targets)  # Returns losses and detections
print(output)

# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x)  # Returns predictions
print(predictions[0])
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:00<00:00, 223MB/s]
# {'loss_classifier': tensor(0.1200, grad_fn=<NllLossBackward0>), 'loss_box_reg': tensor(0.0222, grad_fn=<DivBackward0>), 'loss_objectness': tensor(0.0073, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>), 'loss_rpn_box_reg': tensor(0.0021, grad_fn=<DivBackward0>)}
# {'boxes': tensor([], size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], dtype=torch.int64), 'scores': tensor([], grad_fn=<IndexBackward0>)}

# %%
from engine import train_one_epoch, evaluate

# train on the GPU or on the CPU, if a GPU is not available
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# our dataset has two classes only - background and person
num_classes = 2
# use our dataset and defined transformations
dataset = PennFudanDataset('PennFudanPed', get_transform(train=True))
dataset_test = PennFudanDataset('PennFudanPed', get_transform(train=False))

# split the dataset in train and test set
indices = torch.randperm(len(dataset)).tolist()
dataset = torch.utils.data.Subset(dataset, indices[:-50])
dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    collate_fn=utils.collate_fn
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=1,
    shuffle=False,
    collate_fn=utils.collate_fn
)

# get the model using our helper function
model = get_model_instance_segmentation(num_classes)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)

# let's train it just for 2 epochs
num_epochs = 2

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

print("That's it!")
# Out:
# Downloading: "https://download.pytorch.org/models/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth" to /root/.cache/torch/hub/checkpoints/maskrcnn_resnet50_fpn_coco-bf2d0c1e.pth
# 100%|██████████| 170M/170M [00:00<00:00, 184MB/s]
# /content/data/engine.py:30: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# Epoch: [0]  [ 0/60]  eta: 0:03:06  lr: 0.000090  loss: 3.3434 (3.3434)  loss_classifier: 0.6219 (0.6219)  loss_box_reg: 0.6462 (0.6462)  loss_mask: 2.0229 (2.0229)  loss_objectness: 0.0328 (0.0328)  loss_rpn_box_reg: 0.0196 (0.0196)  time: 3.1121  data: 0.0414  max mem: 2348
# Epoch: [0]  [10/60]  eta: 0:00:22  lr: 0.000936  loss: 1.7952 (1.8484)  loss_classifier: 0.4549 (0.3861)  loss_box_reg: 0.2076 (0.3187)  loss_mask: 0.8646 (1.1224)  loss_objectness: 0.0126 (0.0151)  loss_rpn_box_reg: 0.0038 (0.0060)  time: 0.4414  data: 0.0247  max mem: 2577
# Epoch: [0]  [20/60]  eta: 0:00:12  lr: 0.001783  loss: 0.8736 (1.3726)  loss_classifier: 0.1959 (0.2944)  loss_box_reg: 0.3036 (0.3229)  loss_mask: 0.3415 (0.7323)  loss_objectness: 0.0136 (0.0169)  loss_rpn_box_reg: 0.0038 (0.0062)  time: 0.1676  data: 0.0236  max mem: 3343
# Epoch: [0]  [30/60]  eta: 0:00:07  lr: 0.002629  loss: 0.5827 (1.0670)  loss_classifier: 0.0768 (0.2175)  loss_box_reg: 0.2528 (0.2764)  loss_mask: 0.2200 (0.5549)  loss_objectness: 0.0087 (0.0128)  loss_rpn_box_reg: 0.0048 (0.0055)  time: 0.1460  data: 0.0209  max mem: 3343
# Epoch: [0]  [40/60]  eta: 0:00:04  lr: 0.003476  loss: 0.4052 (0.9064)  loss_classifier: 0.0501 (0.1752)  loss_box_reg: 0.1724 (0.2497)  loss_mask: 0.1756 (0.4664)  loss_objectness: 0.0013 (0.0101)  loss_rpn_box_reg: 0.0034 (0.0051)  time: 0.1337  data: 0.0175  max mem: 3343
# Epoch: [0]  [50/60]  eta: 0:00:02  lr: 0.004323  loss: 0.3017 (0.7879)  loss_classifier: 0.0337 (0.1486)  loss_box_reg: 0.1145 (0.2222)  loss_mask: 0.1552 (0.4037)  loss_objectness: 0.0008 (0.0082)  loss_rpn_box_reg: 0.0037 (0.0052)  time: 0.1371  data: 0.0184  max mem: 3343
# Epoch: [0]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.3017 (0.7298)  loss_classifier: 0.0395 (0.1341)  loss_box_reg: 0.1090 (0.2105)  loss_mask: 0.1453 (0.3721)  loss_objectness: 0.0010 (0.0076)  loss_rpn_box_reg: 0.0037 (0.0056)  time: 0.1357  data: 0.0202  max mem: 3343
# Epoch: [0] Total time: 0:00:11 (0.1959 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:06  model_time: 0.1057 (0.1057)  evaluator_time: 0.0078 (0.0078)  time: 0.1224  data: 0.0083  max mem: 3343
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0380 (0.0555)  evaluator_time: 0.0058 (0.0110)  time: 0.0741  data: 0.0139  max mem: 3343
# Test: Total time: 0:00:04 (0.0807 s / it)
# Averaged stats: model_time: 0.0380 (0.0555)  evaluator_time: 0.0058 (0.0110)
# Accumulating evaluation results...
# DONE (t=0.02s).
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.629
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.808
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.750
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.486
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.636
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.289
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.698
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.698
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.750
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.690
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.697
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.682
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.985
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.859
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.550
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.367
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.696
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.301
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.715
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.718
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.723
# Epoch: [1]  [ 0/60]  eta: 0:00:09  lr: 0.005000  loss: 0.4958 (0.4958)  loss_classifier: 0.0404 (0.0404)  loss_box_reg: 0.1965 (0.1965)  loss_mask: 0.2480 (0.2480)  loss_objectness: 0.0038 (0.0038)  loss_rpn_box_reg: 0.0071 (0.0071)  time: 0.1508  data: 0.0310  max mem: 3343
# Epoch: [1]  [10/60]  eta: 0:00:06  lr: 0.005000  loss: 0.3043 (0.3253)  loss_classifier: 0.0404 (0.0396)  loss_box_reg: 0.0934 (0.1022)  loss_mask: 0.1662 (0.1756)  loss_objectness: 0.0012 (0.0021)  loss_rpn_box_reg: 0.0046 (0.0058)  time: 0.1273  data: 0.0211  max mem: 3343
# Epoch: [1]  [20/60]  eta: 0:00:05  lr: 0.005000  loss: 0.3265 (0.3372)  loss_classifier: 0.0430 (0.0440)  loss_box_reg: 0.0994 (0.1090)  loss_mask: 0.1662 (0.1759)  loss_objectness: 0.0011 (0.0016)  loss_rpn_box_reg: 0.0055 (0.0067)  time: 0.1293  data: 0.0211  max mem: 3343
# Epoch: [1]  [30/60]  eta: 0:00:03  lr: 0.005000  loss: 0.3064 (0.3144)  loss_classifier: 0.0333 (0.0401)  loss_box_reg: 0.0945 (0.1014)  loss_mask: 0.1404 (0.1652)  loss_objectness: 0.0006 (0.0017)  loss_rpn_box_reg: 0.0056 (0.0060)  time: 0.1311  data: 0.0205  max mem: 3343
# Epoch: [1]  [40/60]  eta: 0:00:02  lr: 0.005000  loss: 0.2511 (0.2975)  loss_classifier: 0.0325 (0.0383)  loss_box_reg: 0.0748 (0.0942)  loss_mask: 0.1305 (0.1580)  loss_objectness: 0.0006 (0.0016)  loss_rpn_box_reg: 0.0039 (0.0054)  time: 0.1322  data: 0.0182  max mem: 3343
# Epoch: [1]  [50/60]  eta: 0:00:01  lr: 0.005000  loss: 0.2232 (0.2871)  loss_classifier: 0.0342 (0.0378)  loss_box_reg: 0.0688 (0.0901)  loss_mask: 0.1215 (0.1525)  loss_objectness: 0.0007 (0.0015)  loss_rpn_box_reg: 0.0037 (0.0052)  time: 0.1296  data: 0.0190  max mem: 3343
# Epoch: [1]  [59/60]  eta: 0:00:00  lr: 0.005000  loss: 0.2375 (0.2867)  loss_classifier: 0.0362 (0.0381)  loss_box_reg: 0.0720 (0.0897)  loss_mask: 0.1420 (0.1525)  loss_objectness: 0.0006 (0.0014)  loss_rpn_box_reg: 0.0033 (0.0051)  time: 0.1163  data: 0.0191  max mem: 3343
# Epoch: [1] Total time: 0:00:07 (0.1269 s / it)
# creating index...
# index created!
# Test:  [ 0/50]  eta: 0:00:01  model_time: 0.0280 (0.0280)  evaluator_time: 0.0026 (0.0026)  time: 0.0395  data: 0.0082  max mem: 3343
# Test:  [49/50]  eta: 0:00:00  model_time: 0.0285 (0.0303)  evaluator_time: 0.0037 (0.0055)  time: 0.0516  data: 0.0137  max mem: 3343
# Test: Total time: 0:00:02 (0.0497 s / it)
# Averaged stats: model_time: 0.0285 (0.0303)  evaluator_time: 0.0037 (0.0055)
# Accumulating evaluation results...
# DONE (t=0.01s).
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.776
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.984
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.935
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.514
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.789
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.346
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.827
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.827
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.700
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.810
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.831
# IoU metric: segm
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.719
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.974
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.871
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.325
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.737
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.324
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.760
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.763
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.680
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.773
# That's it!

# %%
import matplotlib.pyplot as plt

from torchvision.utils import draw_bounding_boxes, draw_segmentation_masks


image = read_image("PennFudanPed/PNGImages/FudanPed00046.png")
eval_transform = get_transform(train=False)

model.eval()
with torch.no_grad():
    x = eval_transform(image)
    # convert RGBA -> RGB and move to device
    x = x[:3, ...].to(device)
    predictions = model([x, ])
    pred = predictions[0]


image = (255.0 * (image - image.min()) / (image.max() - image.min())).to(torch.uint8)
image = image[:3, ...]
pred_labels = [f"pedestrian: {score:.3f}" for label, score in zip(pred["labels"], pred["scores"])]
pred_boxes = pred["boxes"].long()
output_image = draw_bounding_boxes(image, pred_boxes, pred_labels, colors="red")

masks = (pred["masks"] > 0.7).squeeze(1)
output_image = draw_segmentation_masks(output_image, masks, alpha=0.5, colors="blue")


plt.figure(figsize=(12, 12))
plt.imshow(output_image.permute(1, 2, 0))

# %%
import matplotlib.pyplot as plt

from torchvision.utils import draw_bounding_boxes, draw_segmentation_masks


image = read_image("PennFudanPed/PNGImages/FudanPed00051.png")
eval_transform = get_transform(train=False)

model.eval()
with torch.no_grad():
    x = eval_transform(image)
    # convert RGBA -> RGB and move to device
    x = x[:3, ...].to(device)
    predictions = model([x, ])
    pred = predictions[0]


image = (255.0 * (image - image.min()) / (image.max() - image.min())).to(torch.uint8)
image = image[:3, ...]
pred_labels = [f"pedestrian: {score:.3f}" for label, score in zip(pred["labels"], pred["scores"])]
pred_boxes = pred["boxes"].long()
output_image = draw_bounding_boxes(image, pred_boxes, pred_labels, colors="red")

masks = (pred["masks"] > 0.5).squeeze(1)
output_image = draw_segmentation_masks(output_image, masks, alpha=0.5, colors="blue")


plt.figure(figsize=(12, 12))
plt.imshow(output_image.permute(1, 2, 0))

# %%
import matplotlib.pyplot as plt

from torchvision.utils import draw_bounding_boxes, draw_segmentation_masks


image = read_image("PennFudanPed/PNGImages/FudanPed00052.png")
eval_transform = get_transform(train=False)

model.eval()
with torch.no_grad():
    x = eval_transform(image)
    # convert RGBA -> RGB and move to device
    x = x[:3, ...].to(device)
    predictions = model([x, ])
    pred = predictions[0]


image = (255.0 * (image - image.min()) / (image.max() - image.min())).to(torch.uint8)
image = image[:3, ...]
pred_labels = [f"pedestrian: {score:.3f}" for label, score in zip(pred["labels"], pred["scores"])]
pred_boxes = pred["boxes"].long()
output_image = draw_bounding_boxes(image, pred_boxes, pred_labels, colors="red")

masks = (pred["masks"] > 0.5).squeeze(1)
output_image = draw_segmentation_masks(output_image, masks, alpha=0.5, colors="blue")


plt.figure(figsize=(12, 12))
plt.imshow(output_image.permute(1, 2, 0))
